# %%
import os, math, random, time
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from PIL import Image
import torch.nn as nn
import torch
import torchvision
import torch.nn.functional as F
import torchvision.transforms as transforms
import torch.optim as optim
from collections import defaultdict
from __future__ import print_function, division
from torch.optim import lr_scheduler
from torch.autograd import Variable
from torchvision import datasets, models, transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils.data import DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def timer_start():
    global t0
    t0 = time.time()
    
def timer_end():   
    print('Time elapsed {:0.1f}s'.format(time.time() - t0))  

def display_grid(data, path, w =10, h =10, columns = 4, rows = 5):
    fig=plt.figure(figsize=(12, 8))
    for i in range(1, columns*rows +1):
        file = data[i]
        file = os.path.join(path, file)
        img = Image.open(file)
        fig.add_subplot(rows, columns, i)
        imshow(img)
    plt.show()
    
def get_best_epcoh(history):
    valid_acc = history['val_acc']
    best_epoch = valid_acc.index(max(valid_acc)) +1
    best_acc =  max(valid_acc)
    print('Best Validation Accuracy Score {:0.5f}, is for epoch {}'.format( best_acc, best_epoch))
    return best_epoch

def plot_results(history):
    tr_acc = history['tr_acc']
    val_acc = history['val_acc']
    tr_loss = history['tr_loss']
    val_loss = history['val_loss']
    epochs = history['epoch']

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, tr_acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')  
    
    plt.subplot(1,2,2)
    plt.plot(epochs, tr_loss, 'b', label = 'Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()
    
def set_seed(seed):
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)

# %% [markdown]
# What is Tensor?
# Tensors are the building blocks for data in PyTorch. Neural networks take tensors as input and produce tensors as outputs. In fact, all operations within a neural network and during optimization are operations between tensors, and all parameters (for example, weights and biases) in a neural network are tensors.

# %% [markdown]
# Tensors are the fundamental data structure in PyTorch. A tensor is an array: that is, a data structure that stores a collection of numbers that are accessible individually using an index, and that can be indexed with multiple indices.

# %% [markdown]
# We need at least one training dataset and one validation dataset to be able to develop and train a model.

# %%
transform = transforms.Compose( [                                  
                                 transforms.Resize((150,150)),
                                 transforms.RandomRotation(10),
                                 transforms.RandomHorizontalFlip(), 
                                 transforms.ToTensor(),
                                  ])

def train_val_dataset(dataset, val_split=0.3):
    train_idx, val_idx = train_test_split(list(range(len(dataset))), test_size=val_split)
    datasets = {}
    datasets['train'] = Subset(dataset, train_idx)
    datasets['val'] = Subset(dataset, val_idx)
    return datasets

dataset = ImageFolder('/content/drive/MyDrive/all/alldata', transform=transform)
print('length of dataset :',len(dataset))
datasets = train_val_dataset(dataset)
print('length of trainset :',len(datasets['train']))
print('length of validation set :',len(datasets['val']))
print(dataset)
# Out:
# length of dataset : 6400
# length of trainset : 4480
# length of validation set : 1920
# Dataset ImageFolder
#     Number of datapoints: 6400
#     Root location: /content/drive/MyDrive/all/alldata
#     StandardTransform
# Transform: Compose(
#                Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                RandomRotation(degrees=[-10.0, 10.0], resample=False, expand=False)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )

# %% [markdown]
# To easily iterate over the data during training, we can create a data loader using the DataLoader class:

# %%
dataloaders = {x:DataLoader(datasets[x], 16, shuffle=True, num_workers=4) for x in ['train','val']}

# %%
inputs, labels = next(iter(dataloaders['train']))
print(inputs.shape, labels.shape)
# Out:
# torch.Size([16, 3, 150, 150]) torch.Size([16])

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.conv2 = nn.Conv2d(16, 32, 3)
        self.conv3 = nn.Conv2d(32, 64, 3)
        self.conv4 = nn.Conv2d(64, 128, 3)
        self.conv5 = nn.Conv2d(128, 128, 3)
        self.pool = nn.MaxPool2d(2)
        self.flat = nn.Flatten()
        self.fc1 = nn.Linear(21632, 1024)
        self.fc2 = nn.Linear(1024, 128)
        self.fc3 = nn.Linear(128, 4)
        

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.flat(x)
        x = F.leaky_relu(self.fc1(x))
        x = nn.Dropout(p=0.3)(x)
        x = F.leaky_relu(self.fc2(x))
        x = torch.softmax(self.fc3(x),dim=1)
        return x

# %%
def train(model, epoch, train_loader, optimizer, criterion) :   
    model.train()
    epoch_loss = correct = 0
    for i, data in enumerate(dataloaders['train'], 0):
        inputs, labels = data[0].to(device), data[1].to(device)    
        optimizer.zero_grad()
        outputs = model(inputs)
        loss =  criterion(outputs, labels)
        _, predicted = torch.max(outputs.data, 1)           
        correct += (predicted == labels).sum().item()  
        loss.backward()
        optimizer.step() 
        epoch_loss += outputs.shape[0] * loss.item()
    accuracy = correct / len(dataloaders['train'].dataset)
    epoch_loss = epoch_loss / len(dataloaders['train'].dataset)
    return epoch_loss, accuracy


def test(model, epoch, test_loader, optimizer, criterion):
    model.eval()
    epoch_loss = correct = 0
    with torch.no_grad():
        for i, data in enumerate(dataloaders['val'], 0):
            images, labels = data[0].to(device), data[1].to(device)
            outputs = model(images)
            loss =    criterion(outputs, labels)
            _, predicted = torch.max(outputs.data, 1)           
            correct += (predicted == labels).sum().item()  
            epoch_loss += outputs.shape[0] * loss.item()
    accuracy = correct / len(dataloaders['val'].dataset)
    epoch_loss = epoch_loss / len(dataloaders['val'].dataset)
    return epoch_loss, accuracy

# %% [markdown]
# By default, PyTorch tensors are stored on the CPU. PyTorch tensors can be utilized on a GPU to speed up computing. This is the main advantage of tensors compared to NumPy arrays. To get this advantage, we need to move the tensors to the CUDA device. We can move tensors onto any device using the .to method:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net()
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)
print('Device: ',device)
model
# Out:
# Device:  cuda:0
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=21632, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=4, bias=True)
# )

# %%
# %%time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

EPOCHS = 200
BATCH_SIZE=16
num_batches = math.ceil(len(datasets['train']) / BATCH_SIZE)

print('Number of Training samples {}, Batch Size {}, Num Batch {}'.format(len(datasets['train']), BATCH_SIZE, num_batches ))

history = defaultdict(list)

for epoch in range( EPOCHS):  
    timer_start()
    print('[Epoch {} of {}]'.format(epoch +1, EPOCHS), end = ' ')
    tr_loss, tr_acc = train(model, epoch, dataloaders['train'], optimizer, criterion)
    val_loss, val_acc = test(model, epoch, dataloaders['val'], optimizer, criterion)  
    timer_end()
    print('tr_loss: {:0.4f},tr_acc {:0.4f}| val_loss {:0.4f}, val_acc {:0.4f}'.format(tr_loss, tr_acc , val_loss, val_acc))
    history['epoch'].append(epoch+1)
    history['tr_loss'].append(round(tr_loss,5))
    history['tr_acc'].append(round(tr_acc,5))
    history['val_loss'].append(round(val_loss,5))
    history['val_acc'].append(round(val_acc,5))
# Out:
# Number of Training samples 4480, Batch Size 16, Num Batch 280
# [Epoch 1 of 200] Time elapsed 513.0s
# tr_loss: 1.2333,tr_acc 0.4989| val_loss 1.2263, val_acc 0.4979
# [Epoch 2 of 200] Time elapsed 14.1s
# tr_loss: 1.2078,tr_acc 0.5174| val_loss 1.2102, val_acc 0.5172
# [Epoch 3 of 200] Time elapsed 14.4s
# tr_loss: 1.1869,tr_acc 0.5317| val_loss 1.1775, val_acc 0.5516
# [Epoch 4 of 200] Time elapsed 14.4s
# tr_loss: 1.1836,tr_acc 0.5335| val_loss 1.1702, val_acc 0.5458
# [Epoch 5 of 200] Time elapsed 14.4s
# tr_loss: 1.1741,tr_acc 0.5451| val_loss 1.1801, val_acc 0.5266
# [Epoch 6 of 200] Time elapsed 14.3s
# tr_loss: 1.1708,tr_acc 0.5458| val_loss 1.1614, val_acc 0.5573
# [Epoch 7 of 200] Time elapsed 14.5s
# tr_loss: 1.1653,tr_acc 0.5551| val_loss 1.1676, val_acc 0.5589
# [Epoch 8 of 200] Time elapsed 14.4s
# tr_loss: 1.1720,tr_acc 0.5498| val_loss 1.1656, val_acc 0.5505
# [Epoch 9 of 200] Time elapsed 14.4s
# tr_loss: 1.1651,tr_acc 0.5609| val_loss 1.1672, val_acc 0.5417
# [Epoch 10 of 200] Time elapsed 14.4s
# tr_loss: 1.1555,tr_acc 0.5650| val_loss 1.1596, val_acc 0.5557
# [Epoch 11 of 200] Time elapsed 14.4s
# tr_loss: 1.1485,tr_acc 0.5779| val_loss 1.1463, val_acc 0.5797
# [Epoch 12 of 200] Time elapsed 14.4s
# tr_loss: 1.1439,tr_acc 0.5813| val_loss 1.1374, val_acc 0.5911
# [Epoch 13 of 200] Time elapsed 14.4s
# tr_loss: 1.1357,tr_acc 0.5967| val_loss 1.1497, val_acc 0.5698
# [Epoch 14 of 200] Time elapsed 14.4s
# tr_loss: 1.1324,tr_acc 0.5960| val_loss 1.1258, val_acc 0.6104
# [Epoch 15 of 200] Time elapsed 14.4s
# tr_loss: 1.1227,tr_acc 0.6105| val_loss 1.1243, val_acc 0.6042
# [Epoch 16 of 200] Time elapsed 14.6s
# tr_loss: 1.1201,tr_acc 0.6116| val_loss 1.1178, val_acc 0.6130
# [Epoch 17 of 200] Time elapsed 14.4s
# tr_loss: 1.1194,tr_acc 0.6129| val_loss 1.1155, val_acc 0.6135
# [Epoch 18 of 200] Time elapsed 14.3s
# tr_loss: 1.1058,tr_acc 0.6283| val_loss 1.1167, val_acc 0.6135
# [Epoch 19 of 200] Time elapsed 14.5s
# tr_loss: 1.1020,tr_acc 0.6297| val_loss 1.1080, val_acc 0.6286
# [Epoch 20 of 200] Time elapsed 14.4s
# tr_loss: 1.0985,tr_acc 0.6371| val_loss 1.1209, val_acc 0.6109
# [Epoch 21 of 200] Time elapsed 14.4s
# tr_loss: 1.0915,tr_acc 0.6417| val_loss 1.1175, val_acc 0.6120
# [Epoch 22 of 200] Time elapsed 14.5s
# tr_loss: 1.0885,tr_acc 0.6489| val_loss 1.1020, val_acc 0.6307
# [Epoch 23 of 200] Time elapsed 14.4s
# tr_loss: 1.0828,tr_acc 0.6531| val_loss 1.0924, val_acc 0.6370
# [Epoch 24 of 200] Time elapsed 14.5s
# tr_loss: 1.0817,tr_acc 0.6549| val_loss 1.0914, val_acc 0.6427
# [Epoch 25 of 200] Time elapsed 14.5s
# tr_loss: 1.0764,tr_acc 0.6612| val_loss 1.0873, val_acc 0.6500
# [Epoch 26 of 200] Time elapsed 14.4s
# tr_loss: 1.0700,tr_acc 0.6667| val_loss 1.0877, val_acc 0.6526
# [Epoch 27 of 200] Time elapsed 14.4s
# tr_loss: 1.0639,tr_acc 0.6790| val_loss 1.0830, val_acc 0.6500
# [Epoch 28 of 200] Time elapsed 14.4s
# tr_loss: 1.0562,tr_acc 0.6817| val_loss 1.0865, val_acc 0.6484
# [Epoch 29 of 200] Time elapsed 14.3s
# tr_loss: 1.0577,tr_acc 0.6797| val_loss 1.0870, val_acc 0.6432
# [Epoch 30 of 200] Time elapsed 14.4s
# tr_loss: 1.0529,tr_acc 0.6848| val_loss 1.0597, val_acc 0.6781
# [Epoch 31 of 200] Time elapsed 14.7s
# tr_loss: 1.0506,tr_acc 0.6859| val_loss 1.0738, val_acc 0.6635
# [Epoch 32 of 200] Time elapsed 14.5s
# tr_loss: 1.0500,tr_acc 0.6911| val_loss 1.0737, val_acc 0.6583
# [Epoch 33 of 200] Time elapsed 14.3s
# tr_loss: 1.0374,tr_acc 0.7011| val_loss 1.0592, val_acc 0.6766
# [Epoch 34 of 200] Time elapsed 14.2s
# tr_loss: 1.0380,tr_acc 0.7054| val_loss 1.0609, val_acc 0.6740
# [Epoch 35 of 200] Time elapsed 14.2s
# tr_loss: 1.0307,tr_acc 0.7127| val_loss 1.0714, val_acc 0.6635
# [Epoch 36 of 200] Time elapsed 14.2s
# tr_loss: 1.0326,tr_acc 0.7054| val_loss 1.0511, val_acc 0.6849
# [Epoch 37 of 200] Time elapsed 14.3s
# tr_loss: 1.0278,tr_acc 0.7129| val_loss 1.0670, val_acc 0.6667
# [Epoch 38 of 200] Time elapsed 14.2s
# tr_loss: 1.0228,tr_acc 0.7188| val_loss 1.0476, val_acc 0.6906
# [Epoch 39 of 200] Time elapsed 14.1s
# tr_loss: 1.0186,tr_acc 0.7219| val_loss 1.0504, val_acc 0.6865
# [Epoch 40 of 200] Time elapsed 14.1s
# tr_loss: 1.0182,tr_acc 0.7185| val_loss 1.0408, val_acc 0.6969
# [Epoch 41 of 200] Time elapsed 14.2s
# tr_loss: 1.0088,tr_acc 0.7362| val_loss 1.0656, val_acc 0.6729
# [Epoch 42 of 200] Time elapsed 14.2s
# tr_loss: 1.0104,tr_acc 0.7272| val_loss 1.0297, val_acc 0.7109
# [Epoch 43 of 200] Time elapsed 14.1s
# tr_loss: 0.9995,tr_acc 0.7422| val_loss 1.0294, val_acc 0.7078
# [Epoch 44 of 200] Time elapsed 14.1s
# tr_loss: 0.9974,tr_acc 0.7433| val_loss 1.0213, val_acc 0.7203
# [Epoch 45 of 200] Time elapsed 14.0s
# tr_loss: 1.0043,tr_acc 0.7382| val_loss 1.0192, val_acc 0.7240
# [Epoch 46 of 200] Time elapsed 14.1s
# tr_loss: 0.9940,tr_acc 0.7504| val_loss 1.0295, val_acc 0.7073
# [Epoch 47 of 200] Time elapsed 14.2s
# tr_loss: 0.9952,tr_acc 0.7453| val_loss 1.0240, val_acc 0.7161
# [Epoch 48 of 200] Time elapsed 14.0s
# tr_loss: 0.9884,tr_acc 0.7525| val_loss 1.0210, val_acc 0.7172
# [Epoch 49 of 200] Time elapsed 14.1s
# tr_loss: 0.9907,tr_acc 0.7520| val_loss 1.0110, val_acc 0.7318
# [Epoch 50 of 200] Time elapsed 14.2s
# tr_loss: 0.9841,tr_acc 0.7605| val_loss 1.0158, val_acc 0.7214
# [Epoch 51 of 200] Time elapsed 14.1s
# tr_loss: 0.9747,tr_acc 0.7656| val_loss 1.0060, val_acc 0.7380
# [Epoch 52 of 200] Time elapsed 14.1s
# tr_loss: 0.9735,tr_acc 0.7690| val_loss 1.0067, val_acc 0.7312
# [Epoch 53 of 200] Time elapsed 14.2s
# tr_loss: 0.9659,tr_acc 0.7788| val_loss 0.9974, val_acc 0.7406
# [Epoch 54 of 200] Time elapsed 14.1s
# tr_loss: 0.9688,tr_acc 0.7708| val_loss 0.9953, val_acc 0.7448
# [Epoch 55 of 200] Time elapsed 14.1s
# tr_loss: 0.9656,tr_acc 0.7795| val_loss 0.9934, val_acc 0.7479
# [Epoch 56 of 200] Time elapsed 14.1s
# tr_loss: 0.9605,tr_acc 0.7801| val_loss 0.9988, val_acc 0.7438
# [Epoch 57 of 200] Time elapsed 14.0s
# tr_loss: 0.9571,tr_acc 0.7850| val_loss 0.9871, val_acc 0.7500
# [Epoch 58 of 200] Time elapsed 14.1s
# tr_loss: 0.9577,tr_acc 0.7848| val_loss 0.9868, val_acc 0.7547
# [Epoch 59 of 200] Time elapsed 14.3s
# tr_loss: 0.9567,tr_acc 0.7871| val_loss 1.0136, val_acc 0.7260
# [Epoch 60 of 200] Time elapsed 14.2s
# tr_loss: 0.9522,tr_acc 0.7888| val_loss 0.9818, val_acc 0.7609
# [Epoch 61 of 200] Time elapsed 14.0s
# tr_loss: 0.9475,tr_acc 0.7949| val_loss 0.9799, val_acc 0.7568
# [Epoch 62 of 200] Time elapsed 14.1s
# tr_loss: 0.9463,tr_acc 0.7967| val_loss 0.9778, val_acc 0.7646
# [Epoch 63 of 200] Time elapsed 14.0s
# tr_loss: 0.9416,tr_acc 0.8004| val_loss 0.9883, val_acc 0.7521
# [Epoch 64 of 200] Time elapsed 14.1s
# tr_loss: 0.9409,tr_acc 0.8016| val_loss 0.9788, val_acc 0.7604
# [Epoch 65 of 200] Time elapsed 14.1s
# tr_loss: 0.9455,tr_acc 0.7953| val_loss 0.9755, val_acc 0.7661
# [Epoch 66 of 200] Time elapsed 14.0s
# tr_loss: 0.9370,tr_acc 0.8056| val_loss 0.9673, val_acc 0.7760
# [Epoch 67 of 200] Time elapsed 14.1s
# tr_loss: 0.9320,tr_acc 0.8123| val_loss 0.9779, val_acc 0.7604
# [Epoch 68 of 200] Time elapsed 14.0s
# tr_loss: 0.9367,tr_acc 0.8065| val_loss 0.9719, val_acc 0.7693
# [Epoch 69 of 200] Time elapsed 14.1s
# tr_loss: 0.9288,tr_acc 0.8143| val_loss 0.9742, val_acc 0.7651
# [Epoch 70 of 200] Time elapsed 14.1s
# tr_loss: 0.9291,tr_acc 0.8161| val_loss 0.9760, val_acc 0.7641
# [Epoch 71 of 200] Time elapsed 14.1s
# tr_loss: 0.9237,tr_acc 0.8183| val_loss 0.9824, val_acc 0.7542
# [Epoch 72 of 200] Time elapsed 14.0s
# tr_loss: 0.9197,tr_acc 0.8223| val_loss 0.9547, val_acc 0.7901
# [Epoch 73 of 200] Time elapsed 14.0s
# tr_loss: 0.9189,tr_acc 0.8252| val_loss 0.9575, val_acc 0.7854
# [Epoch 74 of 200] Time elapsed 14.0s
# tr_loss: 0.9137,tr_acc 0.8317| val_loss 0.9506, val_acc 0.7911
# [Epoch 75 of 200] Time elapsed 14.1s
# tr_loss: 0.9090,tr_acc 0.8366| val_loss 0.9492, val_acc 0.7927
# [Epoch 76 of 200] Time elapsed 14.2s
# tr_loss: 0.9111,tr_acc 0.8313| val_loss 0.9515, val_acc 0.7937
# [Epoch 77 of 200] Time elapsed 14.1s
# tr_loss: 0.9118,tr_acc 0.8317| val_loss 0.9611, val_acc 0.7766
# [Epoch 78 of 200] Time elapsed 14.1s
# tr_loss: 0.9091,tr_acc 0.8344| val_loss 0.9403, val_acc 0.8005
# [Epoch 79 of 200] Time elapsed 14.1s
# tr_loss: 0.8931,tr_acc 0.8511| val_loss 0.9424, val_acc 0.8005
# [Epoch 80 of 200] Time elapsed 14.0s
# tr_loss: 0.8985,tr_acc 0.8469| val_loss 0.9539, val_acc 0.7849
# [Epoch 81 of 200] Time elapsed 14.1s
# tr_loss: 0.8959,tr_acc 0.8500| val_loss 0.9806, val_acc 0.7609
# [Epoch 82 of 200] Time elapsed 14.2s
# tr_loss: 0.8918,tr_acc 0.8513| val_loss 0.9425, val_acc 0.7990
# [Epoch 83 of 200] Time elapsed 14.0s
# tr_loss: 0.8891,tr_acc 0.8569| val_loss 0.9416, val_acc 0.7979
# [Epoch 84 of 200] Time elapsed 14.0s
# tr_loss: 0.8878,tr_acc 0.8545| val_loss 0.9351, val_acc 0.8120
# [Epoch 85 of 200] Time elapsed 14.0s
# tr_loss: 0.8834,tr_acc 0.8629| val_loss 0.9321, val_acc 0.8099
# [Epoch 86 of 200] Time elapsed 14.0s
# tr_loss: 0.8770,tr_acc 0.8670| val_loss 0.9250, val_acc 0.8208
# [Epoch 87 of 200] Time elapsed 14.0s
# tr_loss: 0.8741,tr_acc 0.8696| val_loss 0.9331, val_acc 0.8094
# [Epoch 88 of 200] Time elapsed 14.0s
# tr_loss: 0.8855,tr_acc 0.8589| val_loss 0.9293, val_acc 0.8146
# [Epoch 89 of 200] Time elapsed 13.9s
# tr_loss: 0.8675,tr_acc 0.8788| val_loss 0.9262, val_acc 0.8141
# [Epoch 90 of 200] Time elapsed 13.9s
# tr_loss: 0.8690,tr_acc 0.8752| val_loss 0.9230, val_acc 0.8182
# [Epoch 91 of 200] Time elapsed 14.1s
# tr_loss: 0.8732,tr_acc 0.8696| val_loss 0.9122, val_acc 0.8323
# [Epoch 92 of 200] Time elapsed 14.1s
# tr_loss: 0.8686,tr_acc 0.8761| val_loss 0.9296, val_acc 0.8125
# [Epoch 93 of 200] Time elapsed 14.2s
# tr_loss: 0.8621,tr_acc 0.8833| val_loss 0.9019, val_acc 0.8411
# [Epoch 94 of 200] Time elapsed 14.2s
# tr_loss: 0.8628,tr_acc 0.8801| val_loss 0.9077, val_acc 0.8323
# [Epoch 95 of 200] Time elapsed 14.3s
# tr_loss: 0.8573,tr_acc 0.8873| val_loss 0.9289, val_acc 0.8141
# [Epoch 96 of 200] Time elapsed 14.2s
# tr_loss: 0.8583,tr_acc 0.8866| val_loss 0.8985, val_acc 0.8453
# [Epoch 97 of 200] Time elapsed 14.0s
# tr_loss: 0.8568,tr_acc 0.8902| val_loss 0.8997, val_acc 0.8406
# [Epoch 98 of 200] Time elapsed 14.0s
# tr_loss: 0.8542,tr_acc 0.8915| val_loss 0.8956, val_acc 0.8500
# [Epoch 99 of 200] Time elapsed 14.0s
# tr_loss: 0.8453,tr_acc 0.8984| val_loss 0.8767, val_acc 0.8688
# [Epoch 100 of 200] Time elapsed 14.1s
# tr_loss: 0.8458,tr_acc 0.9000| val_loss 0.8854, val_acc 0.8583
# [Epoch 101 of 200] Time elapsed 14.0s
# tr_loss: 0.8492,tr_acc 0.8942| val_loss 0.9065, val_acc 0.8354
# [Epoch 102 of 200] Time elapsed 14.0s
# tr_loss: 0.8458,tr_acc 0.8982| val_loss 0.8888, val_acc 0.8526
# [Epoch 103 of 200] Time elapsed 14.1s
# tr_loss: 0.8442,tr_acc 0.9013| val_loss 0.8991, val_acc 0.8401
# [Epoch 104 of 200] Time elapsed 14.2s
# tr_loss: 0.8411,tr_acc 0.9040| val_loss 0.8907, val_acc 0.8547
# [Epoch 105 of 200] Time elapsed 14.1s
# tr_loss: 0.8404,tr_acc 0.9062| val_loss 0.8851, val_acc 0.8589
# [Epoch 106 of 200] Time elapsed 14.1s
# tr_loss: 0.8400,tr_acc 0.9042| val_loss 0.8875, val_acc 0.8521
# [Epoch 107 of 200] Time elapsed 14.1s
# tr_loss: 0.8340,tr_acc 0.9098| val_loss 0.8887, val_acc 0.8568
# [Epoch 108 of 200] Time elapsed 14.1s
# tr_loss: 0.8361,tr_acc 0.9096| val_loss 0.8728, val_acc 0.8708
# [Epoch 109 of 200] Time elapsed 14.2s
# tr_loss: 0.8353,tr_acc 0.9100| val_loss 0.8889, val_acc 0.8521
# [Epoch 110 of 200] Time elapsed 14.1s
# tr_loss: 0.8359,tr_acc 0.9078| val_loss 0.8716, val_acc 0.8740
# [Epoch 111 of 200] Time elapsed 14.2s
# tr_loss: 0.8366,tr_acc 0.9083| val_loss 0.9031, val_acc 0.8406
# [Epoch 112 of 200] Time elapsed 14.2s
# tr_loss: 0.8302,tr_acc 0.9145| val_loss 0.8804, val_acc 0.8594
# [Epoch 113 of 200] Time elapsed 14.3s
# tr_loss: 0.8295,tr_acc 0.9172| val_loss 0.8733, val_acc 0.8667
# [Epoch 114 of 200] Time elapsed 14.4s
# tr_loss: 0.8287,tr_acc 0.9150| val_loss 0.8733, val_acc 0.8719
# [Epoch 115 of 200] Time elapsed 14.3s
# tr_loss: 0.8223,tr_acc 0.9219| val_loss 0.8723, val_acc 0.8714
# [Epoch 116 of 200] Time elapsed 14.4s
# tr_loss: 0.8264,tr_acc 0.9181| val_loss 0.8650, val_acc 0.8776
# [Epoch 117 of 200] Time elapsed 14.3s
# tr_loss: 0.8248,tr_acc 0.9185| val_loss 0.8799, val_acc 0.8630
# [Epoch 118 of 200] Time elapsed 14.3s
# tr_loss: 0.8211,tr_acc 0.9243| val_loss 0.8679, val_acc 0.8745
# [Epoch 119 of 200] Time elapsed 14.4s
# tr_loss: 0.8202,tr_acc 0.9246| val_loss 0.8649, val_acc 0.8781
# [Epoch 120 of 200] Time elapsed 14.5s
# tr_loss: 0.8193,tr_acc 0.9259| val_loss 0.8737, val_acc 0.8682
# [Epoch 121 of 200] Time elapsed 14.4s
# tr_loss: 0.8236,tr_acc 0.9214| val_loss 0.8784, val_acc 0.8635
# [Epoch 122 of 200] Time elapsed 14.4s
# tr_loss: 0.8183,tr_acc 0.9263| val_loss 0.8780, val_acc 0.8646
# [Epoch 123 of 200] Time elapsed 14.5s
# tr_loss: 0.8251,tr_acc 0.9183| val_loss 0.8622, val_acc 0.8818
# [Epoch 124 of 200] Time elapsed 14.8s
# tr_loss: 0.8201,tr_acc 0.9246| val_loss 0.8574, val_acc 0.8875
# [Epoch 125 of 200] Time elapsed 14.6s
# tr_loss: 0.8200,tr_acc 0.9243| val_loss 0.8748, val_acc 0.8677
# [Epoch 126 of 200] Time elapsed 14.4s
# tr_loss: 0.8214,tr_acc 0.9228| val_loss 0.8828, val_acc 0.8568
# [Epoch 127 of 200] Time elapsed 14.2s
# tr_loss: 0.8179,tr_acc 0.9263| val_loss 0.8636, val_acc 0.8802
# [Epoch 128 of 200] Time elapsed 14.1s
# tr_loss: 0.8159,tr_acc 0.9283| val_loss 0.8718, val_acc 0.8719
# [Epoch 129 of 200] Time elapsed 14.1s
# tr_loss: 0.8147,tr_acc 0.9290| val_loss 0.8680, val_acc 0.8750
# [Epoch 130 of 200] Time elapsed 14.0s
# tr_loss: 0.8159,tr_acc 0.9283| val_loss 0.8500, val_acc 0.8964
# [Epoch 131 of 200] Time elapsed 14.1s
# tr_loss: 0.8099,tr_acc 0.9357| val_loss 0.8499, val_acc 0.8932
# [Epoch 132 of 200] Time elapsed 14.1s
# tr_loss: 0.8097,tr_acc 0.9346| val_loss 0.8603, val_acc 0.8823
# [Epoch 133 of 200] Time elapsed 14.2s
# tr_loss: 0.8118,tr_acc 0.9321| val_loss 0.8634, val_acc 0.8792
# [Epoch 134 of 200] Time elapsed 14.1s
# tr_loss: 0.8054,tr_acc 0.9391| val_loss 0.8504, val_acc 0.8943
# [Epoch 135 of 200] Time elapsed 14.1s
# tr_loss: 0.8145,tr_acc 0.9295| val_loss 0.8770, val_acc 0.8661
# [Epoch 136 of 200] Time elapsed 14.0s
# tr_loss: 0.8126,tr_acc 0.9326| val_loss 0.8646, val_acc 0.8781
# [Epoch 137 of 200] Time elapsed 14.1s
# tr_loss: 0.8114,tr_acc 0.9330| val_loss 0.8609, val_acc 0.8839
# [Epoch 138 of 200] Time elapsed 14.4s
# tr_loss: 0.8097,tr_acc 0.9339| val_loss 0.8618, val_acc 0.8823
# [Epoch 139 of 200] Time elapsed 14.5s
# tr_loss: 0.8117,tr_acc 0.9328| val_loss 0.8518, val_acc 0.8938
# [Epoch 140 of 200] Time elapsed 14.6s
# tr_loss: 0.8102,tr_acc 0.9330| val_loss 0.8614, val_acc 0.8812
# [Epoch 141 of 200] Time elapsed 14.5s
# tr_loss: 0.8076,tr_acc 0.9355| val_loss 0.8506, val_acc 0.8896
# [Epoch 142 of 200] Time elapsed 14.3s
# tr_loss: 0.8044,tr_acc 0.9391| val_loss 0.8434, val_acc 0.8995
# [Epoch 143 of 200] Time elapsed 14.4s
# tr_loss: 0.7991,tr_acc 0.9460| val_loss 0.8593, val_acc 0.8828
# [Epoch 144 of 200] Time elapsed 14.5s
# tr_loss: 0.8010,tr_acc 0.9442| val_loss 0.8425, val_acc 0.9016
# [Epoch 145 of 200] Time elapsed 14.6s
# tr_loss: 0.8021,tr_acc 0.9426| val_loss 0.8455, val_acc 0.9000
# [Epoch 146 of 200] Time elapsed 14.7s
# tr_loss: 0.8054,tr_acc 0.9393| val_loss 0.8534, val_acc 0.8906
# [Epoch 147 of 200] Time elapsed 15.1s
# tr_loss: 0.8064,tr_acc 0.9386| val_loss 0.8359, val_acc 0.9057
# [Epoch 148 of 200] Time elapsed 14.7s
# tr_loss: 0.8056,tr_acc 0.9386| val_loss 0.8518, val_acc 0.8927
# [Epoch 149 of 200] Time elapsed 14.5s
# tr_loss: 0.8026,tr_acc 0.9411| val_loss 0.8441, val_acc 0.9005
# [Epoch 150 of 200] Time elapsed 14.3s
# tr_loss: 0.8071,tr_acc 0.9366| val_loss 0.8313, val_acc 0.9130
# [Epoch 151 of 200] Time elapsed 14.3s
# tr_loss: 0.7992,tr_acc 0.9449| val_loss 0.8539, val_acc 0.8854
# [Epoch 152 of 200] Time elapsed 14.3s
# tr_loss: 0.7953,tr_acc 0.9496| val_loss 0.8271, val_acc 0.9161
# [Epoch 153 of 200] Time elapsed 14.3s
# tr_loss: 0.8002,tr_acc 0.9437| val_loss 0.8474, val_acc 0.8953
# [Epoch 154 of 200] Time elapsed 14.5s
# tr_loss: 0.7958,tr_acc 0.9482| val_loss 0.8451, val_acc 0.8979
# [Epoch 155 of 200] Time elapsed 14.3s
# tr_loss: 0.8002,tr_acc 0.9437| val_loss 0.8382, val_acc 0.9078
# [Epoch 156 of 200] Time elapsed 14.2s
# tr_loss: 0.8013,tr_acc 0.9420| val_loss 0.8391, val_acc 0.9052
# [Epoch 157 of 200] Time elapsed 14.2s
# tr_loss: 0.7987,tr_acc 0.9464| val_loss 0.8411, val_acc 0.9021
# [Epoch 158 of 200] Time elapsed 14.2s
# tr_loss: 0.7949,tr_acc 0.9496| val_loss 0.8424, val_acc 0.9021
# [Epoch 159 of 200] Time elapsed 14.2s
# tr_loss: 0.7956,tr_acc 0.9480| val_loss 0.8435, val_acc 0.8990
# [Epoch 160 of 200] Time elapsed 14.2s
# tr_loss: 0.7952,tr_acc 0.9498| val_loss 0.8466, val_acc 0.8974
# [Epoch 161 of 200] Time elapsed 14.3s
# tr_loss: 0.7966,tr_acc 0.9480| val_loss 0.8413, val_acc 0.9036
# [Epoch 162 of 200] Time elapsed 14.2s
# tr_loss: 0.7927,tr_acc 0.9525| val_loss 0.8424, val_acc 0.8958
# [Epoch 163 of 200] Time elapsed 14.2s
# tr_loss: 0.7971,tr_acc 0.9471| val_loss 0.8510, val_acc 0.8932
# [Epoch 164 of 200] Time elapsed 14.3s
# tr_loss: 0.8004,tr_acc 0.9435| val_loss 0.8321, val_acc 0.9083
# [Epoch 165 of 200] Time elapsed 14.3s
# tr_loss: 0.7987,tr_acc 0.9455| val_loss 0.8433, val_acc 0.8984
# [Epoch 166 of 200] Time elapsed 14.3s
# tr_loss: 0.7958,tr_acc 0.9475| val_loss 0.8419, val_acc 0.9021
# [Epoch 167 of 200] Time elapsed 14.3s
# tr_loss: 0.7982,tr_acc 0.9455| val_loss 0.8319, val_acc 0.9115
# [Epoch 168 of 200] Time elapsed 14.3s
# tr_loss: 0.7931,tr_acc 0.9502| val_loss 0.8576, val_acc 0.8870
# [Epoch 169 of 200] Time elapsed 14.3s
# tr_loss: 0.7886,tr_acc 0.9563| val_loss 0.8424, val_acc 0.8995
# [Epoch 170 of 200] Time elapsed 14.2s
# tr_loss: 0.7939,tr_acc 0.9496| val_loss 0.8391, val_acc 0.9021
# [Epoch 171 of 200] Time elapsed 14.3s
# tr_loss: 0.7984,tr_acc 0.9444| val_loss 0.8571, val_acc 0.8859
# [Epoch 172 of 200] Time elapsed 14.3s
# tr_loss: 0.7935,tr_acc 0.9502| val_loss 0.8418, val_acc 0.9010
# [Epoch 173 of 200] Time elapsed 14.1s
# tr_loss: 0.7980,tr_acc 0.9460| val_loss 0.8283, val_acc 0.9146
# [Epoch 174 of 200] Time elapsed 14.1s
# tr_loss: 0.7942,tr_acc 0.9509| val_loss 0.8379, val_acc 0.9057
# [Epoch 175 of 200] Time elapsed 14.1s
# tr_loss: 0.7930,tr_acc 0.9509| val_loss 0.8344, val_acc 0.9094
# [Epoch 176 of 200] Time elapsed 14.2s
# tr_loss: 0.7919,tr_acc 0.9525| val_loss 0.8405, val_acc 0.9052
# [Epoch 177 of 200] Time elapsed 14.1s
# tr_loss: 0.7939,tr_acc 0.9504| val_loss 0.8318, val_acc 0.9125
# [Epoch 178 of 200] Time elapsed 14.1s
# tr_loss: 0.7927,tr_acc 0.9507| val_loss 0.8284, val_acc 0.9141
# [Epoch 179 of 200] Time elapsed 14.0s
# tr_loss: 0.7902,tr_acc 0.9527| val_loss 0.8319, val_acc 0.9083
# [Epoch 180 of 200] Time elapsed 13.9s
# tr_loss: 0.7966,tr_acc 0.9469| val_loss 0.8580, val_acc 0.8849
# [Epoch 181 of 200] Time elapsed 14.0s
# tr_loss: 0.7895,tr_acc 0.9554| val_loss 0.8332, val_acc 0.9104
# [Epoch 182 of 200] Time elapsed 14.1s
# tr_loss: 0.7884,tr_acc 0.9556| val_loss 0.8314, val_acc 0.9146
# [Epoch 183 of 200] Time elapsed 14.1s
# tr_loss: 0.7906,tr_acc 0.9540| val_loss 0.8363, val_acc 0.9068
# [Epoch 184 of 200] Time elapsed 14.1s
# tr_loss: 0.7867,tr_acc 0.9554| val_loss 0.8381, val_acc 0.9052
# [Epoch 185 of 200] Time elapsed 13.9s
# tr_loss: 0.7855,tr_acc 0.9587| val_loss 0.8272, val_acc 0.9146
# [Epoch 186 of 200] Time elapsed 14.1s
# tr_loss: 0.7885,tr_acc 0.9549| val_loss 0.8423, val_acc 0.9016
# [Epoch 187 of 200] Time elapsed 14.1s
# tr_loss: 0.7850,tr_acc 0.9583| val_loss 0.8243, val_acc 0.9203
# [Epoch 188 of 200] Time elapsed 14.1s
# tr_loss: 0.7884,tr_acc 0.9551| val_loss 0.8457, val_acc 0.8964
# [Epoch 189 of 200] Time elapsed 14.0s
# tr_loss: 0.7899,tr_acc 0.9540| val_loss 0.8509, val_acc 0.8932
# [Epoch 190 of 200] Time elapsed 14.1s
# tr_loss: 0.7844,tr_acc 0.9596| val_loss 0.8182, val_acc 0.9255
# [Epoch 191 of 200] Time elapsed 14.1s
# tr_loss: 0.7869,tr_acc 0.9569| val_loss 0.8237, val_acc 0.9198
# [Epoch 192 of 200] Time elapsed 14.0s
# tr_loss: 0.7834,tr_acc 0.9612| val_loss 0.8364, val_acc 0.9057
# [Epoch 193 of 200] Time elapsed 14.0s
# tr_loss: 0.7843,tr_acc 0.9596| val_loss 0.8476, val_acc 0.8958
# [Epoch 194 of 200] Time elapsed 14.1s
# tr_loss: 0.7834,tr_acc 0.9609| val_loss 0.8342, val_acc 0.9104
# [Epoch 195 of 200] Time elapsed 14.0s
# tr_loss: 0.7886,tr_acc 0.9554| val_loss 0.8316, val_acc 0.9099
# [Epoch 196 of 200] Time elapsed 14.0s
# tr_loss: 0.7829,tr_acc 0.9614| val_loss 0.8294, val_acc 0.9130
# [Epoch 197 of 200] Time elapsed 14.0s
# tr_loss: 0.7795,tr_acc 0.9650| val_loss 0.8204, val_acc 0.9229
# [Epoch 198 of 200] Time elapsed 13.9s
# tr_loss: 0.7772,tr_acc 0.9672| val_loss 0.8207, val_acc 0.9229
# [Epoch 199 of 200] Time elapsed 13.9s
# tr_loss: 0.7768,tr_acc 0.9674| val_loss 0.8170, val_acc 0.9240
# [Epoch 200 of 200] Time elapsed 14.0s
# tr_loss: 0.7797,tr_acc 0.9638| val_loss 0.8235, val_acc 0.9203
# CPU times: user 13min 4s, sys: 4min 6s, total: 17min 10s
# Wall time: 55min 41s

# %%
plot_results(history)
best_epoch = get_best_epcoh(history)
# Out:
# Best Validation Accuracy Score 0.92552, is for epoch 190
